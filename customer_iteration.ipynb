# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cust1=pd.read_excel('customer (1).xlsx')
cust1.isnull().sum()
# Out:
# id                            0
# attr_flag                     0
# MOBILE                       70
# EMAIL                      2724
# EDUCATIONAL_LEVEL           194
# OCCUPATION                  187
# MARITAL_STATUS              264
# CHILDREN                   5236
# EMAIL_INTIMATION            123
# MOBILE_INTIMATION           121
# DNDTAG                        1
# SEX                          91
# TITLE                         0
# Age of Card                   0
# points_lapsed              5155
# date_lapsed                5155
# age                           0
# months_on_book                0
# acct_age_flag                 0
# reg_visits                   64
# reg_value                    64
# reg_items                    64
# dsc_visits                 1294
# dsc_value                  1294
# dsc_items                  1294
# ret_visits                 4697
# ret_value                  4697
# ret_items                  4697
# disc                       1294
# ...

# %%
plt.figure(figsize=(18,16))
sns.heatmap(cust1.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
cust1["MOBILE"].fillna("Not Provided", inplace = True)
cust1["EMAIL"].fillna("Not Provided", inplace = True)
cust1["EDUCATIONAL_LEVEL"].fillna("N2", inplace = True)
cust1["OCCUPATION"].fillna("N3", inplace = True)
cust1["MARITAL_STATUS"].fillna("S4", inplace = True)
cust1["CHILDREN"].fillna(0, inplace = True)
cust1["EMAIL_INTIMATION"].fillna(0, inplace = True)
cust1["MOBILE_INTIMATION"].fillna(0, inplace = True)
cust1["DNDTAG"].fillna("N5", inplace = True)
cust1["SEX"].fillna("M6", inplace = True)
cust1["TITLE"].fillna(cust1["TITLE"].mode(), inplace = True)
cust1["Age of Card"].fillna(cust1["Age of Card"].mode(), inplace = True)
cust1["points_lapsed"].fillna(0, inplace = True)
cust1["age"].fillna(cust1["age"].mode(), inplace = True)
cust1["months_on_book"].fillna(cust1["months_on_book"].mode(), inplace = True)
cust1["acct_age_flag"].fillna(cust1["acct_age_flag"].mode(), inplace = True)
cust1["reg_visits"].fillna(1, inplace = True)
cust1["reg_value"].fillna(1399, inplace = True)
cust1["reg_items"].fillna(3, inplace = True)
cust1["dsc_visits"].fillna(1, inplace = True)
cust1["dsc_value"].fillna(0, inplace = True)
cust1["dsc_items"].fillna(0, inplace = True)
cust1["ret_visits"].fillna(0, inplace = True)
cust1["ret_value"].fillna(0, inplace = True)
cust1["ret_items"].fillna(0, inplace = True)
cust1["reg_price_for_disc"].fillna(0, inplace = True)
cust1["store_num"].fillna(1, inplace = True)
cust1["city_num"].fillna(1, inplace = True)
cust1["fav_mall_non_mall"].fillna("Mall", inplace = True)
cust1["fav_region"].fillna("WEST", inplace = True)
cust1["fav_city_type"].fillna("METRO", inplace = True)
cust1["last_6_visits"].fillna(1, inplace = True)
cust1["last_6_reg_items"].fillna(2, inplace = True)
cust1["last_6_reg_value"].fillna(4323, inplace = True)
cust1["last_6_ret_visits"].fillna(0, inplace = True)
cust1["last_6_ret_items"].fillna(0, inplace = True)
cust1["last_6_ret_value"].fillna(0, inplace = True)
cust1["months_since_last_purch"].fillna(2, inplace = True)
cust1["months_since_last_ret"].fillna(0, inplace = True)
cust1["disc"].fillna(1925, inplace = True)
cust1["num_prod_class"].fillna(2, inplace = True)

# %%
cust1.drop('date_lapsed',axis=1,inplace=True)

# %%
cust1.drop('last_purch_month',axis=1,inplace=True)
cust1.drop('last_purch_month_dt',axis=1,inplace=True)
cust1.drop('last_ret_month_dt',axis=1,inplace=True)
"""cust1.drop('num_prod_class',axis=1,inplace=True)"""
# Out:
# "cust1.drop('num_prod_class',axis=1,inplace=True)"

# %%
"""cust1.drop('num_prod_class',axis=1,inplace=True)"""
# Out:
# "cust1.drop('num_prod_class',axis=1,inplace=True)"

# %%
cust1.drop('last_ret_month',axis=1,inplace=True)

# %%
cust2=cust1

# %%
figsize=(18,16)
sns.heatmap(cust2.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
print(cust1["num_prod_class"].mode())
# Out:
# 0    2.0
# dtype: float64

# %%
cust2.tail()
# Out:
#         id attr_flag  ... months_since_last_ret num_prod_class
# 5495  5496        Y1  ...                   0.0            2.0
# 5496  5497        Y1  ...                   0.0            6.0
# 5497  5498        Y1  ...                   0.0            3.0
# 5498  5499        Y1  ...                   0.0            2.0
# 5499  5500        Y1  ...                   0.0            6.0
#
# [5 rows x 43 columns]

# %%
cust2.isnull().sum()
# Out:
# id                         0
# attr_flag                  0
# MOBILE                     0
# EMAIL                      0
# EDUCATIONAL_LEVEL          0
# OCCUPATION                 0
# MARITAL_STATUS             0
# CHILDREN                   0
# EMAIL_INTIMATION           0
# MOBILE_INTIMATION          0
# DNDTAG                     0
# SEX                        0
# TITLE                      0
# Age of Card                0
# points_lapsed              0
# age                        0
# months_on_book             0
# acct_age_flag              0
# reg_visits                 0
# reg_value                  0
# reg_items                  0
# dsc_visits                 0
# dsc_value                  0
# dsc_items                  0
# ret_visits                 0
# ret_value                  0
# ret_items                  0
# disc                       0
# reg_price_for_disc         0
# store_num                  0
# city_num                   0
# fav_mall_non_mall          0
# ...

# %%
"""print(cust1["EDUCATIONAL_LEVEL"].mode())
print(cust1["OCCUPATION"].mode())
print(cust1["MARITAL_STATUS"].mode())
print(cust1["DNDTAG"].mode())
print(cust1["reg_visits"].mode())
print(cust1["reg_value"].mode())
print(cust1["reg_items"].mode())
print(cust1["dsc_visits"].mode())
print(cust1["disc"].mean())
print(cust1["store_num"].mode())
print(cust1["city_num"].mode())
print(cust1["fav_region"].mode())
print(cust1["fav_city_type"].mode())
"""

# %%
"""print(cust1["last_6_visits"].mode())
print(cust1["last_6_reg_items"].mode())
print(cust1["last_6_reg_value"].mean())
print(cust1["months_since_last_purch"].mode())"""

# %%
cust3=cust2
cust4=cust3.drop('id',axis=1,inplace=True)

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(cust3.corr(),vmin=-1, vmax=+1, annot=True,linewidths=0.2, cmap='Accent_r')

# %%
sns.set_style('whitegrid')
sns.jointplot(x='disc', y='age', data=cust3, kind='kde')

# %%
sales1=pd.read_excel('sales data.xlsx')

# %%
sns.set_style('whitegrid')
sns.jointplot(x='reg_visits', y='age', data=cust3, kind='kde')

# %%
sns.set_style('whitegrid')
sns.jointplot(x='reg_value', y='age', data=cust3)

# %%
"""enrol1=pd.read_excel('enrolement.xlsx')
enrol1.head(1)"""

# %%
cust2.head(1)
# Out:
#   attr_flag    MOBILE  ... months_since_last_ret num_prod_class
# 0        Y1  Provided  ...                   0.0            5.0
#
# [1 rows x 42 columns]

# %%
"""m1=cust2.join(enrol1, on=id, how='inner')"""

# %%
cust2.head(2)
# Out:
#   attr_flag    MOBILE  ... months_since_last_ret num_prod_class
# 0        Y1  Provided  ...                   0.0            5.0
# 1        Y1  Provided  ...                   0.0            3.0
#
# [2 rows x 42 columns]

# %%
cust3.head(2)
# Out:
#   attr_flag    MOBILE  ... months_since_last_ret num_prod_class
# 0        Y1  Provided  ...                   0.0            5.0
# 1        Y1  Provided  ...                   0.0            3.0
#
# [2 rows x 42 columns]

# %%
cust3.drop('Age of Card',axis=1,inplace=True)
cust3.drop('dsc_value',axis=1,inplace=True)
cust3.drop('dsc_items',axis=1,inplace=True)
cust3.drop('disc',axis=1,inplace=True)
cust3.drop('last_6_ret_items',axis=1,inplace=True)
cust3.drop('last_6_ret_visits',axis=1,inplace=True)

# %%
cust3.head(2)
# Out:
#   attr_flag    MOBILE  ... months_since_last_ret num_prod_class
# 0        Y1  Provided  ...                   0.0            5.0
# 1        Y1  Provided  ...                   0.0            3.0
#
# [2 rows x 36 columns]

# %%
cust3.drop('ret_visits',axis=1,inplace=True)

# %%
cust3.drop('MOBILE',axis=1,inplace=True)

# %%
cust3.head(2)
# Out:
#   attr_flag         EMAIL  ... months_since_last_ret num_prod_class
# 0        Y1      Provided  ...                   0.0            5.0
# 1        Y1  Not Provided  ...                   0.0            3.0
#
# [2 rows x 34 columns]

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(cust3.corr(),vmin=-1, vmax=+1, annot=True,linewidths=0.2, cmap='Accent')

# %%
cust3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5500 entries, 0 to 5499
# Data columns (total 34 columns):
# attr_flag                  5500 non-null object
# EMAIL                      5500 non-null object
# EDUCATIONAL_LEVEL          5500 non-null object
# OCCUPATION                 5500 non-null object
# MARITAL_STATUS             5500 non-null object
# CHILDREN                   5500 non-null float64
# EMAIL_INTIMATION           5500 non-null float64
# MOBILE_INTIMATION          5500 non-null object
# DNDTAG                     5500 non-null object
# SEX                        5500 non-null object
# TITLE                      5500 non-null object
# points_lapsed              5500 non-null float64
# age                        5500 non-null int64
# months_on_book             5500 non-null int64
# acct_age_flag              5500 non-null object
# reg_visits                 5500 non-null float64
# reg_value                  5500 non-null float64
# ...

# %%
attri = pd.get_dummies(cust3['attr_flag'],drop_first=True)
edu = pd.get_dummies(cust3['EDUCATIONAL_LEVEL'],drop_first=True)
occu = pd.get_dummies(cust3['OCCUPATION'],drop_first=True)
marr = pd.get_dummies(cust3['MARITAL_STATUS'],drop_first=True)
email_int = pd.get_dummies(cust3['EMAIL_INTIMATION'],drop_first=True)
mob_int = pd.get_dummies(cust3['MOBILE_INTIMATION'],drop_first=True)
dnd = pd.get_dummies(cust3['DNDTAG'],drop_first=True)
sex = pd.get_dummies(cust3['SEX'],drop_first=True)
title = pd.get_dummies(cust3['TITLE'],drop_first=True)
acct = pd.get_dummies(cust3['acct_age_flag'],drop_first=True)
mall = pd.get_dummies(cust3['fav_mall_non_mall'],drop_first=True)
region = pd.get_dummies(cust3['fav_region'],drop_first=True)
city = pd.get_dummies(cust3['fav_city_type'],drop_first=True)
store_num = pd.get_dummies(cust3['store_num'],drop_first=True)
city_num = pd.get_dummies(cust3['city_num'],drop_first=True)

# %%
"""attri = pd.get_dummies(cust3['attr_flag'],drop_first=True)"""

# %%
cust3.drop(['attr_flag','EDUCATIONAL_LEVEL', 'OCCUPATION', 'MARITAL_STATUS', 'EMAIL_INTIMATION','MOBILE_INTIMATION','DNDTAG', 'SEX','TITLE','acct_age_flag','fav_mall_non_mall','fav_region','fav_city_type','store_num','city_num'] ,axis=1,inplace=True)

# %%
cust3 = pd.concat([cust3,attri, edu, occu, marr, email_int, mob_int, dnd, sex, title,acct,mall,region,city,store_num,city_num],axis=1)

# %%
cust3.head(2)
# Out:
#           EMAIL  CHILDREN  points_lapsed  age  ...  1.0  2.0  3.0  5.0
# 0      Provided       0.0            0.0   31  ...    0    0    1    0
# 1  Not Provided       0.0            0.0   69  ...    1    0    0    0
#
# [2 rows x 56 columns]

# %%
email= pd.get_dummies(cust3['EMAIL'],drop_first=True)

# %%
cust3.drop('EMAIL',axis=1,inplace=True)

# %%
cust3 = pd.concat([cust3, email],axis=1)

# %%
product_id=pd.get_dummies(cust3['num_prod_class'], drop_first=True)

# %%
cust3.drop('num_prod_class',axis=1,inplace=True)

# %%
cust3 = pd.concat([cust3, product_id],axis=1)

# %%
cust3.head(2)
# Out:
#    CHILDREN  points_lapsed  age  months_on_book  ...  9.0  10.0  11.0  12.0
# 0       0.0            0.0   31              43  ...    0     0     0     0
# 1       0.0            0.0   69              29  ...    0     0     0     0
#
# [2 rows x 66 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(cust3.drop('Y1',axis=1), 
                                                    cust3['Y1'], test_size=0.30, 
                                                    random_state=101)

# %%
X_train.head(2)
# Out:
#      CHILDREN  points_lapsed  age  months_on_book  ...  9.0  10.0  11.0  12.0
# 72        2.0            0.0   45              15  ...    0     0     0     0
# 913       0.0            0.0   21               2  ...    0     0     0     0
#
# [2 rows x 65 columns]

# %%
y_train.head(2)
# Out:
# 72     1
# 913    1
# Name: Y1, dtype: uint8

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.24      0.35       325
#            1       0.84      0.97      0.90      1325
#
#     accuracy                           0.83      1650
#    macro avg       0.75      0.60      0.63      1650
# weighted avg       0.80      0.83      0.79      1650

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[  78  247]
#  [  41 1284]]

# %%
"""coeff_df = pd.DataFrame(logmodel.coef_,X.columns,columns=['Coefficient'])
coeff_df"""

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# **Co-eff for Logistic Regression**

# %%
print(logmodel.coef_,X_train.columns)
# Out:
# [[ 3.86651901e-02 -5.37728586e-04  2.08510389e-02  2.46001554e-04
#   -1.59408514e-01 -5.03196928e-05  5.06680828e-02 -2.74052421e-01
#   -6.03435963e-05 -2.80259620e-01 -3.72738226e-05 -1.51606162e-01
#   -7.27520594e-02  7.90312803e-05  2.83237928e-04  3.79793663e-01
#    5.89095997e-02  5.66625806e-03  1.68913013e-01  1.06240765e-03
#    9.13928695e-04 -4.98330940e-03  2.34371514e-01  4.19660848e-03
#    8.98996104e-03  1.76026612e-02  1.29288504e-01 -4.97049135e-02
#   -9.04577546e-02  1.09208797e-03 -1.44907929e-01  1.25893651e-01
#    1.43328136e-01  4.27083420e-02  3.60729837e-02  1.37776854e-01
#    3.99276067e-02  1.12534737e-01 -7.78643666e-02  1.08992209e-01
#    1.42498988e-01 -2.82095416e-02  3.20560653e-03 -1.71087683e-01
#    3.82720589e-02 -3.55790166e-02 -1.11989348e-02 -2.66108607e-05
#    0.00000000e+00  1.70662692e-01 -4.95410468e-02 -2.19116696e-03
#    0.00000000e+00  1.43950248e-01  5.01712525e-02  8.06148824e-02
# ...

# %% [markdown]
# **DECISION TREE CLASSIFIER**

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,rfc_pred))
# Out:
# [[  81  244]
#  [  47 1278]]

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.25      0.35       325
#            1       0.84      0.96      0.90      1325
#
#     accuracy                           0.82      1650
#    macro avg       0.73      0.60      0.62      1650
# weighted avg       0.80      0.82      0.79      1650

# %%
print(logmodel.coef_)
# Out:
# [[ 1.60060583e-01 -4.37148354e-04  1.21607506e-02 -3.60689001e-03
#   -1.73656414e-01 -4.56977163e-05  4.40698972e-02 -2.89728561e-01
#   -4.27339723e-05 -3.60345967e-01 -3.63553646e-05 -2.31605627e-01
#   -5.01754062e-02  6.61680988e-05  3.33683055e-04  4.15930696e-01
#    7.39177625e-02  2.20628048e-02  2.23098777e-01  1.07930827e-02
#    3.27496627e-02 -1.24966703e-02  4.90320670e-01  2.16480334e-02
#    4.51545758e-02  6.80282335e-02  6.40431453e-02 -1.60125694e-01
#   -3.07226025e-01  6.47851143e-03 -2.60487788e-01  1.54000137e-01
#    4.36528453e-02  1.56562818e-02  1.88657904e-01  2.04665436e-01
#    4.08179923e-02  3.86705166e-01  4.11133365e-02  1.93745548e-01
#   -7.67006087e-02  1.13663202e-01  1.66935479e-01 -1.63317991e-01
#    2.08543731e-02 -4.24097170e-01  6.38920671e-02 -9.95808281e-02
#   -3.95658436e-02  2.47805457e-03  0.00000000e+00  1.33070306e-01
#   -7.90100891e-02 -2.93228012e-03  0.00000000e+00  1.12247230e-01
# ...

# %%
sns.set_style('whitegrid')
sns.jointplot(x='reg_value', y= 'months_since_last_purch', data=cust2, kind='kde')

# %%
cust2.head()
# Out:
#           EMAIL  CHILDREN  ...  months_since_last_ret  num_prod_class
# 0      Provided       0.0  ...                    0.0             5.0
# 1  Not Provided       0.0  ...                    0.0             3.0
# 2  Not Provided       0.0  ...                    0.0             3.0
# 3  Not Provided       0.0  ...                    0.0             2.0
# 4  Not Provided       0.0  ...                    0.0             1.0
#
# [5 rows x 19 columns]

# %%
cust2.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-feac5b955a96> in <module>()
# ----> 1 cust2.tail()
#
# NameError: name 'cust2' is not defined
